# %%
import skimage
im = skimage.io.imread("0.bmp")
import numpy as np
np.savetxt('1.csv', im, fmt='%.4f', delimiter=',')
import subprocess
result = subprocess.check_output([str('finger.exe'),str('1.csv')])
result
# Out:
# b'\r\n0.000000,0.000000,0.000000,\r\n0.000000,0.000000,0.000000,\r\n0.000000,0.000000,0.000000,\r\n0.000000,0.000000,0.000000,\r\n0.000000,0.000000,0.000000,\r\n0.000000,0.000000,0.000000,\r\n0.000000,0.000000,0.000000,\r\n0.000000,0.000000,0.000000,\r\n0.000000,0.000000,0.000000,\r\n0.000000,0.000000,0.000000,\r\n0.000000,0.000000,0.000000,\r\n0.000000,0.000000,0.000000,\r\n0.000000,0.000000,0.000000,\r\n0.000000,0.000000,0.000000,\r\n0.000000,0.000000,0.000000,\r\n0.000000,0.000000,0.000000,\r\n0.000000,0.000000,0.000000,\r\n0.000000,0.000000,0.000000,\r\n0.000000,0.000000,0.000000,\r\n0.000000,0.000000,0.000000,\r\n0.000000,0.000000,0.000000,\r\n0.000000,0.000000,0.000000,\r\n0.000000,0.000000,0.000000,\r\n0.000000,0.000000,0.000000,\r\n0.000000,0.000000,0.000000,\r\n0.000000,0.000000,0.000000,\r\n0.000000,0.000000,0.000000,\r\n0.000000,0.000000,0.000000,\r\n0.000000,0.000000,0.000000,\r\n0.000000,0.000000,0.000000,\r\n0.000000,0.000000,0.000000,\r\n0.000000,0.000000,0.000000,\r\n
# ...
